# %% [markdown]
# ## 基于《全宋词》的风格可视化和聚类分析 ##
#
# 2016302580149 赵世晗

# %%
# 导入相关的库文件

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
import os
import random

import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from constants import WordType, DISPLAY_COUNT, POET_COUNT, WORD_COULD_COUNT, FAVORITE_POETS_LIST
from analyzer import plot_vectors, get_analyzer
from preprocessor import StemResult
from sklearn.cluster import KMeans

# %%
# 确定保存位置
saved_dir = os.path.join(os.curdir, "out")

# 对宋词进行分词
result = StemResult()
result = result.stem_poem("ci.song.all.json", saved_dir)

# 用word2vector和tfidf算法对所有宋词数据进行学习和分析，得到词向量
analyzer = get_analyzer(result, saved_dir)
# Out:
# load existed stem result.
# load existed analyzer.

# %%
# 装填词人的词向量信息
tf_idf_vector_list = []
tf_idf_vector_dimension_list = []
w2v_vector_list = []
w2v_vector_dimension_list = []
poet_list = []
for c in result.poet_counter.most_common(POET_COUNT):
    poet = c[0]
    index = analyzer.poets.index(poet)
    w2v_vector_list.append(analyzer.w2v_word_vector_tsne[index])
    w2v_vector_dimension_list.append(analyzer.w2v_word_vector[index])
    tf_idf_vector_list.append(analyzer.tfidf_word_vector_tsne[index])
    tf_idf_vector_dimension_list.append(analyzer.tfidf_word_vector[index])
    poet_list.append(poet)

# %% [markdown]
# ### 以下测试用降维后的tf_idf和word2vector绘制诗人散点图
#
# ### 这里仅选取创作量前100的诗人

# %%
# 绘制散点图
plot_vectors(tf_idf_vector_list, poet_list, 'tf_idf')

# %%
plot_vectors(w2v_vector_list, poet_list, 'w2v')

# %% [markdown]
# ### 比较tf_idf和word2vector降维后的聚类效果，以区域范围呈现

# %%
def draw_area(figure, X, target, specific_poets, title, subplot):
    """绘制多个诗人区域图"""
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    ax = plt.subplot(120 + subplot)
    x_axis = []
    y_axis = []

    for i in range(X.shape[0]):
        x_axis.append(X[i, 0])
        y_axis.append(X[i, 1])

    ax.scatter(x_axis, y_axis, c='b', marker='o')

    first_point = []
    last_point = []
    for i in range(X.shape[0]):
        if target[i] in specific_poets:
            if len(last_point):
                ax.plot([last_point[0], X[i, 0]], [last_point[1], X[i, 1]], color='r')
            else:
                first_point = [X[i, 0], X[i, 1]]
            last_point = [X[i, 0], X[i, 1]]
            ax.text(X[i, 0], X[i, 1], target[i])
    ax.plot([last_point[0], first_point[0]], [last_point[1], first_point[1]], color='r')
    plt.title(title)


def draw_compared_plot(specified_poets, group_name):
    fig = plt.figure()
    draw_area(fig, tf_idf_vector_list, poet_list, specified_poets, title='TF-IDF', subplot=1)
    draw_area(fig, w2v_vector_list, poet_list, specified_poets, title='Word2Vector', subplot=2)
    plt.suptitle('{}的距离可视化'.format(group_name))
    plt.show()

# %%
draw_compared_plot(["苏轼", "辛弃疾", "贺铸", "陈亮", "张元干", "刘过"], "豪放派")

# %%
draw_compared_plot(["柳永", "张先", "晏殊", "欧阳修", "秦观", "李清照"], "婉约派")

# %%
draw_compared_plot(["黄庭坚", "秦观", "晁补之", "张耒"], "苏门四学士")

# %%
draw_compared_plot(["周邦彦", "姜夔", "吴文英", "张炎", "王沂孙"], "格律派诗人")

# %%
draw_compared_plot(["晏殊", "晏几道", "欧阳修", "黄庭坚"], "江西词派")

# %% [markdown]
# #### 从大体上看，tf_idf和word2vector两种词向量表示各有优劣，相对来讲word2vector的数据更加精确一些
#
# ### 以下是词频分析

# %%
print('统计分析')
print('-----------------')
print('统计了%s位词人的%s首词' % (len(result.poet_counter.keys()), sum(result.poet_counter.values())))
# Out:
# 统计分析
# -----------------
# 统计了1468位词人的21047首词

# %%
def show_counter(counter):
    for k, v in counter:
        print(k, v)

    print()

# %%
print("写作数量排名：")
most_productive_poets = result.poet_counter.most_common(DISPLAY_COUNT)
show_counter(most_productive_poets)
# Out:
# 写作数量排名：
# 无名氏 1568
# 辛弃疾 629
# 苏轼 362
# 刘辰翁 354
# 吴文英 341
# 赵长卿 339
# 张炎 302
# 贺铸 282
# 刘克庄 269
# 晏几道 260

# %%
print("最常用的非单字词：")
cnt = 0
most_frequent_words = []
for word, count in result.word_counter.most_common():
    if cnt >= WORD_COULD_COUNT:
        break
    if len(word) > 1:
        most_frequent_words.append((word, count))
        cnt += 1
show_counter(most_frequent_words[:DISPLAY_COUNT])
# Out:
# 最常用的非单字词：
# 东风 1221
# 何处 1091
# 人间 1053
# 风流 754
# 西风 715
# 春风 705
# 归来 682
# 梅花 660
# 江南 657
# 归去 611

# %%
def show_wordcloud(word_dict, title=None):
    wordcloud = WordCloud(
        font_path='fonts/msyh.ttf',
        background_color='white',
        scale=2,
    ).fit_words(word_dict)
    plt.imshow(wordcloud)
    plt.axis("off")
    if title:
        plt.title(title)
    plt.show()

# %% [markdown]
# ### 绘制全宋词的最高频词云

# %%
most_frequent_word_dict = {}
for word in most_frequent_words:
    most_frequent_word_dict[word[0]] = word[1]

show_wordcloud(most_frequent_word_dict, '全宋词词云')

# %%
print("最常用的名词：")
most_common_nouns = result.word_property_counter_dict[WordType.NOUN].most_common(DISPLAY_COUNT)
show_counter(most_common_nouns)
# Out:
# 最常用的名词：
# 人 4323
# 酒 1625
# 梦 1596
# 处 1429
# 风 1357
# 雨 1317
# 东风 1221
# 人间 1053
# 事 1028
# 烟 989

# %%
print("最常用的地名：")
show_counter(result.word_property_counter_dict[WordType.PLACE].most_common(DISPLAY_COUNT))
# Out:
# 最常用的地名：
# 江南 657
# 香 475
# 西湖 297
# 长安 276
# 青山 258
# 云 253
# 千古 238
# 江山 227
# 夕阳 200
# 重阳 194

# %%
print("最常用的形容词：")
show_counter(result.word_property_counter_dict[WordType.ADJ].most_common(DISPLAY_COUNT))
# Out:
# 最常用的形容词：
# 好 1793
# 新 1469
# 老 1449
# 长 1055
# 香 1042
# 远 972
# 红 957
# 小 874
# 轻 870
# 难 864

# %%
print("最常用的连词：")
show_counter(result.word_property_counter_dict[WordType.CONJ].most_common(DISPLAY_COUNT))
# Out:
# 最常用的连词：
# 和 1107
# 且 990
# 但 873
# 并 312
# 不是 276
# 何时 243
# 若 227
# 如此 217
# 尽 212
# 只有 204

# %%
print("最常用的数词：")
show_counter(result.word_property_counter_dict[WordType.NUM].most_common(DISPLAY_COUNT))
# Out:
# 最常用的数词：
# 月 3084
# 一 2858
# 年 1657
# 日 1216
# 多 1023
# 两 705
# 岁 639
# 半 627
# 三 580
# 多少 562

# %%
print("最常用的介词：")
show_counter(result.word_property_counter_dict[WordType.PREP].most_common(DISPLAY_COUNT))
# Out:
# 最常用的介词：
# 与 2536
# 在 2193
# 为 2051
# 向 1268
# 把 1266
# 对 1234
# 凭 792
# 自 779
# 被 734
# 同 622

# %%
print("最常用的动词：")
show_counter(result.word_property_counter_dict[WordType.VERB].most_common(DISPLAY_COUNT))
# Out:
# 最常用的动词：
# 是 3687
# 有 3140
# 去 2614
# 来 2514
# 看 2043
# 笑 1818
# 如 1774
# 愁 1603
# 无 1543
# 醉 1540

# %% [markdown]
# ### 这里直接使用w2v_model自带的most_similar()函数来实现相关性的计算

# %%
print("**基于词向量的分析")
for word in list(most_common_nouns):
    print("与 %s 相关的词：" % word[0])
    show_counter(analyzer.find_similar_word(word[0]))
# Out:
# **基于词向量的分析
# 与 人 相关的词：
# 何处 0.864283561706543
# 无人 0.8515129089355469
# 不 0.839759349822998
# 天涯 0.8257339596748352
# 空 0.8244014978408813
# 行人 0.814522385597229
# 情 0.8073403835296631
# 长安 0.8030989170074463
# 犹 0.8017246723175049
# 相思 0.7991102933883667
#
# 与 酒 相关的词：
# 俎 0.852088451385498
# 前 0.8196625709533691
# 醉 0.8139654397964478
# 劝 0.8008391261100769
# 杯 0.79901123046875
# 觞 0.7946414947509766
# 对 0.794021487236023
# 卮 0.7917488217353821
# 倒 0.783812940120697
# 清 0.7687764167785645
#
# 与 梦 相关的词：
# 魂 0.725357711315155
# 山 0.6823581457138062
# 天涯 0.6713723540306091
# 江南 0.6503053307533264
# 处 0.6418209075927734
# 何处 0.6339840888977051
# 路 0.6316040754318237
# 断肠 0.6296807527542114
# 空 0.6268713474273682
# 随 0.6212582588195801
#
# 与 处 相关的词：
# 想 0.8877575397491455
# 空 0.8555024862289429
# 最 0.8520615100860596
# 一点 0.8497570753097534
# 千里 0.8497368097305298
# 疑 0.8479198217391968
# 扬州 0.8474084138870239
# 无人 0.8434222936630249
# 犹 0.8419791460037231
# 青山 0.8409715890884399
#
# 与 风 相关的词：
# 溪 0.8458561897277832
# 枝 0.8422526717185974
# 疏 0.8364447355270386
# 雪 0.8253272771835327
# 阴 0.8199785351753235
# 凉 0.8150866031646729
# 透 0.814917802810669
# 柳 0.8111109733581543
# 弄 0.8087632060050964
# 香 0.8081707954406738
#
# 与 雨 相关的词：
# 晴 0.9346196055412292
# 海棠 0.9141784310340881
# 晚 0.8912397623062134
# 吹 0.8909200429916382
# 莺 0.8872573375701904
# 渐 0.8815618753433228
# 阴 0.8814742565155029
# 残 0.8814572095870972
# 杨柳 0.878327488899231
# 一番 0.8772608637809753
#
# 与 东风 相关的词：
# 暮 0.9383541345596313
# 莺 0.9317048788070679
# 燕子 0.92808997631073
# 西风 0.9217526912689209
# 吹 0.916354775428772
# 雁 0.895169734954834
# 燕 0.8949614763259888
# 落花 0.890812337398529
# 晚 0.8860279321670532
# 芳草 0.8824188709259033
#
# 与 人间 相关的词：
# 吾 0.9815568327903748
# 真 0.9808042049407959
# 风流 0.9783865213394165
# 此 0.9771941900253296
# 之 0.9716209173202515
# 平生 0.9702959656715393
# 富贵 0.963991641998291
# 功名 0.9637210369110107
# 当年 0.9637040495872498
# 人生 0.9624472856521606
#
# 与 事 相关的词：
# 多 0.962938666343689
# 算 0.95447838306427
# 功名 0.9497833251953125
# 少 0.9466867446899414
# 人生 0.9396294355392456
# 今 0.9364458322525024
# 些 0.9318134784698486
# 要 0.9312773942947388
# 矣 0.9284299612045288
# 作 0.9259985685348511
#
# 与 烟 相关的词：
# 翠 0.9815104007720947
# 斜 0.9813882112503052
# 帘 0.977479100227356
# 冷 0.9702399969100952
# 栊 0.9694997072219849
# 卷 0.9679933786392212
# 绣 0.967921257019043
# 淡 0.9672572612762451
# 帘幕 0.9642401933670044
# 窗 0.9622198343276978

# %% [markdown]
# ### 个人喜爱的一些词人的数据分析

# %%
def print_poet_detail(poet_name):
    print("与 %s 用词相近的诗人：" % poet_name)
    print("tf-idf标准： %s" % analyzer.find_similar_poet(poet_name))
    print("word2vector标准： %s\n" % analyzer.find_similar_poet(poet_name, use_w2v=True))
    print("%s 最常用的词牌统计:" % poet_name)
    show_counter(result.poet_cipai_counter[poet_name].most_common(DISPLAY_COUNT))

    cnt = 0
    most_frequent_words = []
    for word, count in result.poet_word_counter[poet_name].most_common():
        if cnt >= WORD_COULD_COUNT:
            break
        if len(word) > 1:
            most_frequent_words.append((word, count))
            cnt += 1
    most_frequent_word_dict = {}
    for word in most_frequent_words:
        most_frequent_word_dict[word[0]] = word[1]

    show_wordcloud(most_frequent_word_dict, poet_name)

# %%
print_poet_detail("辛弃疾")
# Out:
# 与 辛弃疾 用词相近的诗人：
# tf-idf标准： 刘辰翁
# word2vector标准： 方岳
#
# 辛弃疾 最常用的词牌统计:
# 鹧鸪天 63
# 水调歌头 38
# 满江红 34
# 贺新郎 24
# 临江仙 24
# 念奴娇 22
# 菩萨蛮 22
# 浣溪沙 20
# 西江月 17
# 玉楼春 17

# %%
print_poet_detail("张孝祥")
# Out:
# 与 张孝祥 用词相近的诗人：
# tf-idf标准： 辛弃疾
# word2vector标准： 赵善括
#
# 张孝祥 最常用的词牌统计:
# 浣溪沙 30
# 菩萨蛮 22
# 鹧鸪天 18
# 水调歌头 16
# 西江月 13
# 减字木兰花 10
# 鹊桥仙 8
# 踏莎行 8
# 虞美人 7
# 念奴娇 7

# %%
print_poet_detail("苏轼")
# Out:
# 与 苏轼 用词相近的诗人：
# tf-idf标准： 辛弃疾
# word2vector标准： 韩元吉
#
# 苏轼 最常用的词牌统计:
# 浣溪沙 46
# 减字木兰花 28
# 菩萨蛮 22
# 南歌子 18
# 南乡子 17
# 西江月 15
# 蝶恋花 15
# 临江仙 14
# 江城子 12
# 定风波 11

# %%
print_poet_detail("陈亮")
# Out:
# 与 陈亮 用词相近的诗人：
# tf-idf标准： 辛弃疾
# word2vector标准： 吴潜
#
# 陈亮 最常用的词牌统计:
# 贺新郎 6
# 水调歌头 4
# 点绛唇 4
# 念奴娇 3
# 好事近 3
# 桂枝香 2
# 三部乐 2
# 祝英台近 2
# 洞仙歌 2
# 踏莎行 2

# %% [markdown]
# ### 对tf_idf和word2vector两种词向量数据进行K均值聚类分析，这里尝试将宋代词人分为豪放，婉约两大派别

# %%
# 聚类分析
cluster = KMeans(n_clusters=2, random_state=0)
labels = cluster.fit_predict(tf_idf_vector_dimension_list)

for i in range(2):
    print('--Group {}----'.format(i + 1))
    for j in range(len(labels)):
        if i == labels[j]:
            print(poet_list[j] + ",", end=" ")
    print()
# Out:
# --Group 1----
# 无名氏, 辛弃疾, 刘克庄, 张孝祥, 李曾伯, 魏了翁, 王之道, 张元干, 曹勋, 史浩, 杨无咎, 向子, 赵彦端, 赵师侠, 葛长庚, 洪适, 郭应祥, 张抡, 陈著, 曾觌, 侯置, 吕胜己, 沈瀛, 葛胜仲, 丘, 方岳, 刘过, 仲殊, 王千秋, 陈三聘, 姚述尧2, 管鉴, 汪莘, 赵以夫, 曹冠, 卢炳, 汪元量, 张继先, 陈师道, 李纲, 黄裳, 王炎2, 舒づ, 张榘, 赵善括, 黄人杰, 程大昌,
# --Group 2----
# 苏轼, 刘辰翁, 吴文英, 赵长卿, 张炎, 贺铸, 晏几道, 吴潜, 朱敦儒, 欧阳修, 柳永, 陈允平, 毛滂, 韩, 黄庭坚, 周邦彦, 蔡伸, 晁补之, 张先, 程垓, 周紫芝, 石孝友, 周密, 陆游, 晁端礼, 晏殊, 吕渭老, 仇远, 范成大, 史达祖, 高观国, 叶梦得, 袁去华, 蒋捷, 李之仪, 卢祖皋, 黄机, 方千里, 张, 杨泽民, 秦观, 姜夔, 杜安世, 李弥逊, 韩元吉, 王质, 陈亮, 王沂孙, 陈德武, 谢逸, 王安中, 陈克, 李清照,

# %%
# 聚类分析
cluster = KMeans(n_clusters=2, random_state=0)
labels = cluster.fit_predict(w2v_vector_dimension_list)

for i in range(2):
    print('--Group {}----'.format(i + 1))
    for j in range(len(labels)):
        if i == labels[j]:
            print(poet_list[j] + ",", end=" ")
    print()
# Out:
# --Group 1----
# 无名氏, 辛弃疾, 苏轼, 刘辰翁, 张炎, 刘克庄, 吴潜, 朱敦儒, 张孝祥, 韩, 李曾伯, 黄庭坚, 魏了翁, 史浩, 杨无咎, 向子, 晁补之, 赵彦端, 陆游, 晁端礼, 葛长庚, 洪适, 郭应祥, 张抡, 陈著, 叶梦得, 李之仪, 黄机, 吕胜己, 沈瀛, 姜夔, 葛胜仲, 韩元吉, 丘, 方岳, 刘过, 陈亮, 王千秋, 陈三聘, 姚述尧2, 管鉴, 汪莘, 赵以夫, 陈德武, 卢炳, 张继先, 陈师道, 李纲, 黄裳, 王炎2, 张榘, 赵善括, 黄人杰, 程大昌,
# --Group 2----
# 吴文英, 赵长卿, 贺铸, 晏几道, 欧阳修, 柳永, 陈允平, 毛滂, 周邦彦, 王之道, 张元干, 曹勋, 蔡伸, 张先, 程垓, 周紫芝, 石孝友, 赵师侠, 周密, 晏殊, 吕渭老, 仇远, 范成大, 史达祖, 高观国, 曾觌, 袁去华, 蒋捷, 侯置, 卢祖皋, 方千里, 张, 杨泽民, 秦观, 杜安世, 李弥逊, 王质, 仲殊, 王沂孙, 曹冠, 谢逸, 汪元量, 王安中, 陈克, 李清照, 舒づ,

# %% [markdown]
# #### 可以看到两种分类方法都有瑕疵，存在将一些诗人错分的情况。主要原因是数据量不够，总共仅有21000+诗词作品。但是相对而言由于word2vector存在词向量的关联性运算，词风分布较为疏散，因此聚类效果好一些。
